# %% [markdown]
# ### Calcular

# %%
valor_hora = float(input("Quanto você ganha por hora?"))
horas_trabalhadas = int(input("Quantas horas você trabalhou?"))
calcular = valor_hora * horas_trabalhadas

print(f"Você ganhou R${calcular:.2f} neste mês")
# Out:
# Você ganhou R$3000.00 neste mês
